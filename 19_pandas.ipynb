# %%
import pandas as pd

# %%
data_path="organizations-10000.csv"
df=pd.read_csv(data_path)
# print(df.head())
df.head()
# Out:
#    Index  Organization Id                         Name  \
# 0      1  522816eF8fdBE6d                 Mckinney PLC
# 1      2  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2      3  428B397eA2d7290                   Ruiz-Walls
# 3      4  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4      5  6CDCcdE3D0b7b44       Diaz, Robles and Haley
#
#                          Website  \
# 0               http://soto.com/
# 1      http://harding-duffy.com/
# 2         http://www.atkins.biz/
# 3           http://salazar.info/
# 4  https://www.brooks-scott.net/
#
#                                              Country  \
# 0                                          Sri Lanka
# 1                                            Namibia
# 2                                               Iran
# 3  British Indian Ocean Territory (Chagos Archipe...
# 4                                           Botswana
#
#                                   Description  Founded  \
# ...

# %%
df.tail(2)
# Out:
#       Index  Organization Id         Name                     Website  \
# 9998   9999  01D2539e270CEbd  Wolfe-Mckee       http://www.parks.com/
# 9999  10000  0D3b7DcFA21d92d     Beck LLC  https://wagner-glover.com/
#
#       Country                                   Description  Founded  \
# 9998     Togo                  Balanced value-added ability     1975
# 9999  Georgia  Decentralized context-sensitive service-desk     2007
#
#                     Industry  Number of employees
# 9998  Environmental Services                 2505
# 9999                Wireless                 4552

# %%
df.min()
# Out:
# Index                                          1
# Organization Id                  001d9DeBfFD6DD3
# Name                                  Abbott Inc
# Website                       http://abbott.net/
# Country                              Afghanistan
# Description            Adaptive 24/7 focus group
# Founded                                     1970
# Industry                              Accounting
# Number of employees                            1
# dtype: object

# %%
df.sample(4)
# Out:
#       Index  Organization Id          Name                         Website  \
# 4639   4640  D16D48C9d7eAF9b   Rosales Inc      http://dickson-melton.org/
# 62       63  bF269f627Eee5c9   Hoffman Ltd        https://www.rogers.info/
# 6857   6858  CC4EaD9e1e7CFb3  Campos-Giles          http://www.lowery.com/
# 7577   7578  D05AfA0D3De62bF   Lynch Group  http://www.figueroa-henry.org/
#
#              Country                           Description  Founded  \
# 4639           Nauru  Open-architected responsive protocol     1984
# 62          Honduras             Operative 24hour leverage     1994
# 6857  Czech Republic       Intuitive client-driven archive     2011
# 7577       Singapore          Organic grid-enabled adapter     1974
#
#                          Industry  Number of employees
# 4639                  Fundraising                 4949
# 62                      Furniture                 5896
# 6857  Non - Profit / Volunteering                 8303
# ...

# %%
df.describe()
# Out:
#              Index       Founded  Number of employees
# count  10000.00000  10000.000000         10000.000000
# mean    5000.50000   1995.776700          4961.321000
# std     2886.89568     14.991608          2911.862096
# min        1.00000   1970.000000             1.000000
# 25%     2500.75000   1983.000000          2446.750000
# 50%     5000.50000   1996.000000          4894.000000
# 75%     7500.25000   2009.000000          7530.000000
# max    10000.00000   2022.000000          9999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                10000 non-null  int64
#  1   Organization Id      10000 non-null  object
#  2   Name                 10000 non-null  object
#  3   Website              10000 non-null  object
#  4   Country              10000 non-null  object
#  5   Description          10000 non-null  object
#  6   Founded              10000 non-null  int64
#  7   Industry             10000 non-null  object
#  8   Number of employees  10000 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 703.3+ KB

# %%
df.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
df['Number of employees']
# Out:
# 0       3930
# 1       7871
# 2       3095
# 3       5422
# 4       3135
#         ...
# 9995    6123
# 9996    9043
# 9997    8951
# 9998    2505
# 9999    4552
# Name: Number of employees, Length: 10000, dtype: int64

# %%
type(df['Name'])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
(df[['Name']])
# Out:
#                              Name
# 0                    Mckinney PLC
# 1                  Cunningham LLC
# 2                      Ruiz-Walls
# 3     Parrish, Osborne and Clarke
# 4          Diaz, Robles and Haley
# ...                           ...
# 9995           Neal, Day and Wang
# 9996    Barrett, Rojas and Adkins
# 9997               Franklin-Ayala
# 9998                  Wolfe-Mckee
# 9999                     Beck LLC
#
# [10000 rows x 1 columns]

# %%
(df[['Number of employees']])
# Out:
#       Number of employees
# 0                    3930
# 1                    7871
# 2                    3095
# 3                    5422
# 4                    3135
# ...                   ...
# 9995                 6123
# 9996                 9043
# 9997                 8951
# 9998                 2505
# 9999                 4552
#
# [10000 rows x 1 columns]

# %%
df.Name # we don't use . notation because it is difficult to differentitate whether it is attribute or column
# Out:
# 0                      Mckinney PLC
# 1                    Cunningham LLC
# 2                        Ruiz-Walls
# 3       Parrish, Osborne and Clarke
# 4            Diaz, Robles and Haley
#                    ...
# 9995             Neal, Day and Wang
# 9996      Barrett, Rojas and Adkins
# 9997                 Franklin-Ayala
# 9998                    Wolfe-Mckee
# 9999                       Beck LLC
# Name: Name, Length: 10000, dtype: object

# %%
df['Number of employees'].mean()
# Out:
# np.float64(4961.321)

# %%
df['Number of employees'].median()
# Out:
# np.float64(4894.0)

# %%
df['Country'].mode()
# Out:
# 0    Congo
# Name: Country, dtype: object

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates() #to remove duplicates value
# Out:
#       Index  Organization Id                         Name  \
# 0         1  522816eF8fdBE6d                 Mckinney PLC
# 1         2  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2         3  428B397eA2d7290                   Ruiz-Walls
# 3         4  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4         5  6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...     ...              ...                          ...
# 9995   9996  2EE82AD1Cd045cd           Neal, Day and Wang
# 9996   9997  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9997   9998  B4B92A44e0331Bc               Franklin-Ayala
# 9998   9999  01D2539e270CEbd                  Wolfe-Mckee
# 9999  10000  0D3b7DcFA21d92d                     Beck LLC
#
#                             Website  \
# 0                  http://soto.com/
# 1         http://harding-duffy.com/
# 2            http://www.atkins.biz/
# 3              http://salazar.info/
# 4     https://www.brooks-scott.net/
# ...                             ...
# ...

# %%
# df=df.drop_duplicates() 
#esko replacement ko thau ma yo garney!!!
df.drop_duplicates(inplace=True) # this means updating the df(data frame)

# %%
new_df=df.drop_duplicates(['Country'])
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 1251
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                243 non-null    int64
#  1   Organization Id      243 non-null    object
#  2   Name                 243 non-null    object
#  3   Website              243 non-null    object
#  4   Country              243 non-null    object
#  5   Description          243 non-null    object
#  6   Founded              243 non-null    int64
#  7   Industry             243 non-null    object
#  8   Number of employees  243 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 19.0+ KB

# %%
new_df=df.drop_duplicates(['Country','Founded','Industry'])
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9980 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                9980 non-null   int64
#  1   Organization Id      9980 non-null   object
#  2   Name                 9980 non-null   object
#  3   Website              9980 non-null   object
#  4   Country              9980 non-null   object
#  5   Description          9980 non-null   object
#  6   Founded              9980 non-null   int64
#  7   Industry             9980 non-null   object
#  8   Number of employees  9980 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 779.7+ KB

# %%
new_df.reset_index(drop=True)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9980 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                9980 non-null   int64
#  1   Organization Id      9980 non-null   object
#  2   Name                 9980 non-null   object
#  3   Website              9980 non-null   object
#  4   Country              9980 non-null   object
#  5   Description          9980 non-null   object
#  6   Founded              9980 non-null   int64
#  7   Industry             9980 non-null   object
#  8   Number of employees  9980 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 779.7+ KB

# %%
df.drop('Index',axis=1,inplace=True)
df.head(2)
# Out:
#    Organization Id            Name                    Website    Country  \
# 0  522816eF8fdBE6d    Mckinney PLC           http://soto.com/  Sri Lanka
# 1  70C7FBD7e6Aa3Ea  Cunningham LLC  http://harding-duffy.com/    Namibia
#
#                             Description  Founded Industry  Number of employees
# 0       Synergized global system engine     1988    Dairy                 3930
# 1  Team-oriented fault-tolerant adapter     2018  Library                 7871

# %%
df.drop(['Organization Id', 'Website'],axis=1,inplace=True)
df.head(2)
# Out:
#              Name    Country                           Description  Founded  \
# 0    Mckinney PLC  Sri Lanka       Synergized global system engine     1988
# 1  Cunningham LLC    Namibia  Team-oriented fault-tolerant adapter     2018
#
#   Industry  Number of employees
# 0    Dairy                 3930
# 1  Library                 7871

# %%
df.rename(columns={'Number of employees':'N_emp','Founded':'Established'},inplace=True)
df.head(2)
# Out:
#              Name    Country                           Description  \
# 0    Mckinney PLC  Sri Lanka       Synergized global system engine
# 1  Cunningham LLC    Namibia  Team-oriented fault-tolerant adapter
#
#    Established Industry  N_emp
# 0         1988    Dairy   3930
# 1         2018  Library   7871

# %%
df['Country'].unique()
# Out:
# array(['Sri Lanka', 'Namibia', 'Iran',
#        'British Indian Ocean Territory (Chagos Archipelago)', 'Botswana',
#        'Ecuador', 'Sierra Leone', 'Zimbabwe', 'Timor-Leste', 'Ukraine',
#        'United Kingdom', 'Thailand', 'Turkey', 'Kiribati', 'Canada',
#        'Colombia', 'Suriname', 'Burundi', 'Kazakhstan', 'Malta',
#        'Andorra', 'Yemen', 'Central African Republic', 'Swaziland',
#        'Brazil', 'Bangladesh', 'Ghana', 'Isle of Man',
#        'Russian Federation', 'Iraq', 'Kenya', 'Belarus', 'Moldova',
#        'Albania', 'Paraguay', 'Togo', 'Korea', 'Macedonia', 'Morocco',
#        'Sudan', 'Lesotho', 'Mauritania', 'Uruguay', 'French Guiana',
#        'Indonesia', 'Macao', 'Holy See (Vatican City State)', 'Uganda',
#        'Portugal', "Cote d'Ivoire", 'Jamaica', 'Bolivia', 'Uzbekistan',
#        'Falkland Islands (Malvinas)', 'Svalbard & Jan Mayen Islands',
#        'Honduras', 'Vanuatu', 'Hungary', 'Western Sahara', 'Somalia',
# ...

# %%
df['Country'].nunique()
# Out:
# 243

# %%
pd.get_dummies(df['Country'], drop_first=True).head()
# Out:
#    Albania  Algeria  American Samoa  Andorra  Angola  Anguilla  \
# 0    False    False           False    False   False     False
# 1    False    False           False    False   False     False
# 2    False    False           False    False   False     False
# 3    False    False           False    False   False     False
# 4    False    False           False    False   False     False
#
#    Antarctica (the territory South of 60 deg S)  Antigua and Barbuda  \
# 0                                         False                False
# 1                                         False                False
# 2                                         False                False
# 3                                         False                False
# 4                                         False                False
#
#    Argentina  Armenia  ...  Uruguay  Uzbekistan  Vanuatu  Venezuela  Vietnam  \
# 0      False    False  ...    False       False    False      False    False
# ...
