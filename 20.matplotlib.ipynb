# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x_cor=[1,4]
y_cor=[2,1]

# %%
plt.plot(x_cor,y_cor)
plt.show()

# %%
plt.plot(x_cor,y_cor,linewidth=5)
plt.show()

# %%
plt.plot(x_cor,y_cor,marker='o')
plt.show()

# %%
plt.plot(x_cor,y_cor,marker='*',ms=15,mfc='red',mec='green')
plt.show()

# %%
x=[1,2,3,4,5]
y=[2,4,2,4,2]

# %%
plt.scatter(x,y)
plt.grid(axis='y')
plt.show()

# %%
plt.bar(x,y)
plt.show()
# Out:
# <BarContainer object of 5 artists>

# %%
import random
random.randint(1,100)
# Out:
# 83

# %%
num=[random.randint(1,100) for i in range(100)]

# %%
plt.hist(num,bins=40,orientation='horizontal')
plt.show()

# %%
random.seed(42)
x=[random.randint(50,100) for i in range(10)]
x
# Out:
# [90, 57, 51, 97, 67, 65, 64, 58, 97, 56]

# %%
import string
# string.ascii_letters
label=[''.join(random.choices(string.ascii_letters,k=2)) for i in range(10)]
label
# Out:
# ['cx', 'gV', 'ep', 'GU', 'sj', 'dI', 'OZ', 'ST', 'tx', 'Ri']

# %%
explodes=[0.5 if label=='sj' else 0 for label in label]
explodes
# Out:
# [0, 0, 0, 0, 0.5, 0, 0, 0, 0, 0]

# %%
plt.pie(x,labels=label,explode=explodes)
plt.show()

# %%
nrows=2
ncols=2

# %%
plt.subplot(nrows,ncols,1)
plt.plot(x_cor,y_cor)


plt.subplot(nrows,ncols,2)
plt.plot(x_cor,y_cor,marker='o',ms=15,mfc='red',mec='blue')


plt.subplot(nrows,ncols,3)
plt.hist(num,bins=40,orientation='horizontal')


plt.subplot(nrows,ncols,4)
plt.pie(x,labels=label,explode=explodes)
plt.show()

# %%
x=[1,2]
y=[2,3]
font1={'family':'serif','color':'blue','size':10}
font2={'family':'serif','color':'darkred','size':20,'weight':'bold'}

plt.plot(x,y)
plt.xlabel("x-label",fontdict=font1)
plt.ylabel("y-label", fontdict=font1)
plt.title("Title",loc='left',fontdict=font2)
# Out:
# Text(0.0, 1.0, 'Title')

# %% [markdown]
# ### Write a list comprehension such that even number should be replaced by 0 and keep the odd number as it is
# - input [1,2,3,4]
# - output [1,0,3,0]
# ```python
# #given list
# l=range(1,12)

# %%
inp=range(1,12)
out=[0 if i%2==0 else i for i in inp]
print(out)
# Out:
# [1, 0, 3, 0, 5, 0, 7, 0, 9, 0, 11]

# %% [markdown]
# ###WAP to reverse the string elements in the list
# - input: ['abc','def,'ghi']
# - output: ['cba,'fed','ihg]

# %%
inp=['Utsarga','Manish','Waibhawa']
print([i[::-1] for i in inp])
# Out:
# ['agrastU', 'hsinaM', 'awahbiaW']
